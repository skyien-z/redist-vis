# %%
import csv
import geopandas
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import keplergl

# %%
def read_partition(partition_fname):
    """
    Reads a partition (district map) from a csv file with 
    columns 'GEOID' (unique identifiers for the census tracts) and 'district'. 
    
    Returns a pandas DataFrame object representing the map, where
    'GEOID' is the key.
    """
    with open(partition_fname, 'r') as map_file:
        map_reader = csv.reader(map_file)
        map_raw = list(map_reader)

    map_headers = map_raw.pop(0)
    map_df = pd.DataFrame(map_raw, columns=map_headers).astype({'district': int})
    return map_df.set_index('GEOID')

# %%
def get_sample_wi_gdf(tracts_fname, partition_fname):
    """
    Loads a sample Wisconsin district map. 

    Parameters:
        tracts_fname: the name of the Wisconsin census tracts file (zipped shapefile)
        partition_fname: the name of the initial partition file (.csv)

    Returns:
        the given Wisconsin district map as a GeoPandas DataFrame object
    """
    # Step 1. Build a GeoDataFrame (a geographic version of a pandas DataFrame)
    # from the tracts zip file (adding 'zip://' prefix if missing). 
    tracts_fname = tracts_fname if 'zip://' in tracts_fname else 'zip://' + tracts_fname
    gdf = geopandas.read_file(tracts_fname)
    gdf.set_index('GEOID', inplace=True)

    # Step 2. Load the initial partition and join it to the GeoDataFrame. 
    map_df = read_partition(partition_fname)
    map_gdf = gdf.join(map_df)

    map_gdf['district'].fillna(value=-1, inplace=True) # Slight cleanup
    
    return map_gdf

# %%
if __name__ == '__main__':
    tracts_fname = 'data/tl_2013_55_tract.zip'
    partition_fname = 'data/wi_gerrymander_dem.csv'

    sample_gdf = get_sample_wi_gdf(tracts_fname, partition_fname)
    
sample_gdf
# Out:
#             STATEFP COUNTYFP TRACTCE     NAME              NAMELSAD  MTFCC  \
# GEOID
# 55009940002      55      009  940002  9400.02  Census Tract 9400.02  G5020
# 55009001600      55      009  001600       16       Census Tract 16  G5020
# 55009001801      55      009  001801    18.01    Census Tract 18.01  G5020
# 55009001802      55      009  001802    18.02    Census Tract 18.02  G5020
# 55009002001      55      009  002001    20.01    Census Tract 20.01  G5020
# ...             ...      ...     ...      ...                   ...    ...
# 55043960800      55      043  960800     9608     Census Tract 9608  G5020
# 55043960100      55      043  960100     9601     Census Tract 9601  G5020
# 55043960500      55      043  960500     9605     Census Tract 9605  G5020
# 55043961100      55      043  961100     9611     Census Tract 9611  G5020
# 55043960600      55      043  960600     9606     Census Tract 9606  G5020
#
#             FUNCSTAT      ALAND    AWATER     INTPTLAT      INTPTLON  \
# GEOID
# 55009940002        S   11517097         0  +44.5145501  -088.1271594
# 55009001600        S    3660554     33519  +44.4885958  -087.9835008
# 55009001801        S   11447611     45849  +44.5146596  -087.9165411
# 55009001802        S   19321287  20945836  +44.5246043  -087.9801080
# 55009002001        S    6978578         0  +44.4979025  -087.9593343
# ...              ...        ...       ...          ...           ...
# 55043960800        S  253212075  15985750  +42.7117442  -090.6232730
# 55043960100        S  364751521   3687082  +43.0851261  -090.5338605
# 55043960500        S  569009923  31227383  +42.8066244  -090.8677346
# 55043961100        S  188425817  10413672  +42.6224044  -090.5533699
# 55043960600        S  495953369     40951  +42.8491370  -090.5857485
#
#                                                       geometry  district
# GEOID
# 55009940002  POLYGON ((-88.15018 44.51202, -88.15010 44.513...       8.0
# 55009001600  POLYGON ((-88.00246 44.48693, -87.99766 44.488...       8.0
# 55009001801  POLYGON ((-87.95519 44.51945, -87.95512 44.519...       8.0
# 55009001802  POLYGON ((-88.00750 44.53416, -88.00528 44.538...       8.0
# 55009002001  POLYGON ((-87.98522 44.50493, -87.98260 44.505...       8.0
# ...                                                        ...       ...
# 55043960800  POLYGON ((-90.78594 42.75890, -90.78579 42.759...       4.0
# 55043960100  POLYGON ((-90.65769 43.05224, -90.65765 43.052...       4.0
# 55043960500  POLYGON ((-91.07932 42.82298, -91.07897 42.825...       4.0
# 55043961100  POLYGON ((-90.69007 42.60893, -90.68964 42.609...       4.0
# 55043960600  POLYGON ((-90.82488 42.78242, -90.82475 42.782...       4.0
#
# [1409 rows x 13 columns]

# %% [markdown]
# assign config = hex_config
# %run hex_config.ipynb

# %%
if __name__ == '__main__':
    tracts_fname = 'data/tl_2013_55_tract.zip'
    partition_fname = 'data/wi_gerrymander_dem.csv'

    sample_gdf = get_sample_wi_gpd(tracts_fname, partition_fname)

    wisconsin_map = keplergl.KeplerGl()
    wisconsin_map.add_data(sample_gdf, "district")
#wisconsin_map.config
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter

# %%
wisconsin_map.save_to_html(file_name='first_map.html')
# Out:
# Map saved to first_map.html!
